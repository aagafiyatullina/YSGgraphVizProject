# %%
import pandas as pd

articles = pd.read_csv('articles.csv', sep='|')
author = pd.read_csv('author.csv', sep='|')
commentator = pd.read_csv('commentator.csv', sep='|')

# %%
author
# Out:
#                    author                                            article  \
# 0             [Syurmakov]  [Создаем с нуля собственную нейронную сеть на ...
# 1            [shulyndina]  [Приглашаем выступить на PyCon Russia 2019 / Б...
# 2               [yaheads]  [Вдохновлялись продакшеном и баскетболом: как ...
# 3                 [ilk1n]           [Окей, Google: как пройти капчу? / Хабр]
# 4          [tormozedison]  [ПО для управления роборукой, автоматически оп...
# 5          [flacoshinobi]  [Машинное обучение для всех, кто изучал матема...
# 6           [LukaSafonov]  [Обман автоматизированных камер наблюдения / Б...
# 7                [olepav]  [AI-интерфейсы и где они обитают / Блог компан...
# 8           [OShapovalov]  [Большой адронный коллайдер и Одноклассники / ...
# 9               [nidalee]  [Увеличение видео 1080P до 4К, или Как я научи...
# 10          [Kamil_Safin]  [Так сложно найти, легко пропустить и невозмож...
# ...

# %%
extra = author.iloc[1830]['title']

# %%
import numpy as np

# %%
author = author.replace(np.nan, '[AI@MIPT: Большие данные для математических моделей человеческого генома / Блог компании Московский физико-технический институт (МФТИ) / Хабр]')

# %%
author
# Out:
#                    author                                            article  \
# 0             [Syurmakov]  [Создаем с нуля собственную нейронную сеть на ...
# 1            [shulyndina]  [Приглашаем выступить на PyCon Russia 2019 / Б...
# 2               [yaheads]  [Вдохновлялись продакшеном и баскетболом: как ...
# 3                 [ilk1n]           [Окей, Google: как пройти капчу? / Хабр]
# 4          [tormozedison]  [ПО для управления роборукой, автоматически оп...
# 5          [flacoshinobi]  [Машинное обучение для всех, кто изучал матема...
# 6           [LukaSafonov]  [Обман автоматизированных камер наблюдения / Б...
# 7                [olepav]  [AI-интерфейсы и где они обитают / Блог компан...
# 8           [OShapovalov]  [Большой адронный коллайдер и Одноклассники / ...
# 9               [nidalee]  [Увеличение видео 1080P до 4К, или Как я научи...
# 10          [Kamil_Safin]  [Так сложно найти, легко пропустить и невозмож...
# ...

# %%
del author['title']

# %%
author
# Out:
#                    author                                            article
# 0             [Syurmakov]  [Создаем с нуля собственную нейронную сеть на ...
# 1            [shulyndina]  [Приглашаем выступить на PyCon Russia 2019 / Б...
# 2               [yaheads]  [Вдохновлялись продакшеном и баскетболом: как ...
# 3                 [ilk1n]           [Окей, Google: как пройти капчу? / Хабр]
# 4          [tormozedison]  [ПО для управления роборукой, автоматически оп...
# 5          [flacoshinobi]  [Машинное обучение для всех, кто изучал матема...
# 6           [LukaSafonov]  [Обман автоматизированных камер наблюдения / Б...
# 7                [olepav]  [AI-интерфейсы и где они обитают / Блог компан...
# 8           [OShapovalov]  [Большой адронный коллайдер и Одноклассники / ...
# 9               [nidalee]  [Увеличение видео 1080P до 4К, или Как я научи...
# 10          [Kamil_Safin]  [Так сложно найти, легко пропустить и невозмож...
# ...

# %%
articles
# Out:
#                                                   title  a_id
# 0     [Создаем с нуля собственную нейронную сеть на ...     0
# 1     [Приглашаем выступить на PyCon Russia 2019 / Б...     1
# 2     [Вдохновлялись продакшеном и баскетболом: как ...     2
# 3              [Окей, Google: как пройти капчу? / Хабр]     3
# 4     [ПО для управления роборукой, автоматически оп...     4
# 5     [Машинное обучение для всех, кто изучал матема...     5
# 6     [Обман автоматизированных камер наблюдения / Б...     6
# 7     [AI-интерфейсы и где они обитают / Блог компан...     7
# 8     [Большой адронный коллайдер и Одноклассники / ...     8
# 9     [Увеличение видео 1080P до 4К, или Как я научи...     9
# 10    [Так сложно найти, легко пропустить и невозмож...    10
# 11    [С бородой, в тёмных очках и в профиль: трудны...    11
# 12                [Введение в машинное обучение / Хабр]    12
# 13    [SNA Hackathon 2019 — итоги / Блог компании Од...    13
# ...

# %%
commentator
# Out:
#                                                    title   commentator
# 0      [Создаем с нуля собственную нейронную сеть на ...     Syurmakov
# 1      [Создаем с нуля собственную нейронную сеть на ...       ivanych
# 2      [Создаем с нуля собственную нейронную сеть на ...  Here_and_Now
# 3      [Создаем с нуля собственную нейронную сеть на ...     Sanovskiy
# 4      [Создаем с нуля собственную нейронную сеть на ...   GokenTanmay
# 5      [Создаем с нуля собственную нейронную сеть на ...          lair
# 6      [Создаем с нуля собственную нейронную сеть на ...   GokenTanmay
# 7      [Создаем с нуля собственную нейронную сеть на ...          lair
# 8      [Создаем с нуля собственную нейронную сеть на ...   Psychopompe
# 9      [Создаем с нуля собственную нейронную сеть на ...     M00nL1ght
# 10     [Создаем с нуля собственную нейронную сеть на ...         TiesP
# 11     [Создаем с нуля собственную нейронную сеть на ...     M00nL1ght
# ...

# %%
articles.to_csv('articles.csv', mode='w', index=False, sep='|')
author.to_csv('author.csv', mode='w', index=False, sep='|')
commentator.to_csv('commentator.csv', mode='w', index=False, sep='|')
